# %%
import pandas as pd
import sqlite3

# Load the CSV file into a DataFrame
csv_file_path = '/content/TS_Max10_repeats2.csv'  # Update this to the path of your CSV file
df = pd.read_csv(csv_file_path)

# Create a connection to the SQLite database
# If the file doesn't exist, SQLite will create it
db_file_path = '/content/assessment.db'  # Update this to where you want your database file
conn = sqlite3.connect(db_file_path)

# Write the data to a table named 'your_table_name'
# If the table already exists, consider adding replace or append as needed
df.to_sql('TP_Max10_repeats2', conn, if_exists='replace', index=False)

# Close the connection to the database
conn.close()
