# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b480673a-0fbd-4b0e-b755-262f1012b4b0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b480673a-0fbd-4b0e-b755-262f1012b4b0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Load data from the first sheet (or whichever sheet you specify) of the Excel file
df1 = pd.read_excel('Max_Wells_CO_C.xlsx', sheet_name='Sheet1')
df2 = pd.read_excel('CO_U and CO_C Wells with Ra data DNR merged -S&G in MCOAS.xlsx', sheet_name='CO_U')

# We perform an inner join on 'WI_UNIQUE_'. This will only keep rows where the 'WI_UNIQUE_' is present in both dataframes.
df_common = pd.merge(df1, df2, how='inner', on='WI_UNIQUE_')

# Check which columns have timezones datetime64[ns, UTC]
print(df_common.dtypes)

# Replace 'date' with your actual column name which has datetime64[ns, UTC]
# Remove timezone from the 'date' column
df_common['Sample Date_x'] = df_common['Sample Date_x'].dt.tz_localize(None)

# Write the result to a new Excel file
df_common.to_excel('output.xlsx', index=False)

from pandas import ExcelWriter
import pytz
from datetime import datetime

data = pd.DataFrame(data={"ID":[1,2],
                          'LocalDateTime':['2020-06-19 12:38:48+05:30','2020-06-30 12:38:48+05:30']})

data['LocalDateTime'] = pd.to_datetime(data['LocalDateTime'])

data['LocalDateTime'] = data['LocalDateTime'].apply(lambda a: datetime.strftime(a,"%Y-%m-%d %H:%M:%S"))

data['LocalDateTime'] = pd.to_datetime(data['LocalDateTime'])


writer = pd.ExcelWriter(rC:\Users\Desktop\testData.xlsx",
                        engine='xlsxwriter'
                        ,datetime_format='dd-mmm-yyyy')
data.to_excel(writer, sheet_name='Sheet1')
writer.save()

data.info()
# Out:
# WI_UNIQUE_        object
# Sample Date_x      int64
# Measured A_x     float64
# Contaminan        object
# Measured A_y     float64
#                   ...
# INVT_BEDRO       float64
# INVT_WELL_       float64
# INVT_BY_LI       float64
# INVT_AFFIL       float64
# GRN_SAMPLE        object
# Length: 95, dtype: object
# <ipython-input-6-1509938590ca>:5: FutureWarning: Inferring datetime64[ns, UTC] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns, UTC])
#   df2 = pd.read_excel('CO_U and CO_C Wells with Ra data DNR merged -S&G in MCOAS.xlsx', sheet_name='CO_U')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-1509938590ca> in <cell line: 15>()
#      13 # Replace 'date' with your actual column name which has datetime64[ns, UTC]
# ...
