# %%
def traverseArray(nums):
  for i in range(len(nums)):
    print(nums[i], end = ' ')

nums = [1,2,3,4,5]
traverseArray(nums)
# Out:
# 1 2 3 4 5

# %%
def return_val(nums, i, j):
  return nums[i][j]

nums = [[1,2],[3,4]]
return_val(nums,0,1)
# Out:
# 2
