# %%
import pandas as pd

# Read the Excel file into a DataFrame
df = pd.read_excel('CO_U and CO_C Wells with Ra data DNR merged -S&G in MCOAS.xlsx')

# Access the columns of interest
unique_well_number = df['WI_UNIQUE_']
sample_dates = df['Sample Date']
measured_amount = df['Measured A']

# Iterate over the data in the columns
for i in range(len(df)):
    well_number = unique_well_number[i]
    date = sample_dates[i]
    amount = measured_amount[i]

    # Do something with the data
    print(f"Well Number: {well_number}, Date: {date}, Amount: {amount}")

    # Perform further processing or calculations as needed
    # You can also convert data types if required, for example:
    # parsed_date = pd.to_datetime(date, format='%m/%d/%Y')
    # parsed_amount = float(amount)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Sample Date'
#
# The above exception was the direct cause of the following exception:
#
# ...
