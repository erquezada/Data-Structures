# %%
def print_hello():
  hello = "Hello World"
  return hello

def print_numbers():
  for number in range(0, 10):
    if number % 2 == 0: # if number is even print number
      print(number)
    else: # else print hello
      pass
  return number

def main():
  if print_numbers() % 2 == 1:
    pass
  else:
    print(print_hello())


if __name__ == "__main__":
  main()
# Out:
# 0
# 2
# 4
# 6
# 8
