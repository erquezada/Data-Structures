# %%
from docx import Document

# Create a new Document
doc = Document()

# Add the main title
doc.add_heading("Practice Problems for Exam", level=1)

# Add each problem section
doc.add_heading("1. Which of the following best describes the backtracking algorithm?", level=2)
doc.add_paragraph(
    "• Option A: Backtracking systematically generates and checks all possible solutions, without eliminating any partial possibilities along the way.\n"
    "• Option B: Backtracking incrementally constructs potential solutions, abandoning them and going back when it becomes clear that they cannot lead to a valid complete solution.\n"
    "• Option C: It randomly selects partial solutions and tests them to see if they lead to the final solution.\n"
    "• Option D: It tries all solutions in parallel, selecting the best option after all paths are explored.\n"
)

doc.add_heading("2. Master Theorem", level=2)
doc.add_paragraph(
    "Consider the following recurrence equation form:\n"
    "T(n) = aT(n/b) + n^k\n\n"
    "• T(n) = O(n^log_b a) if a > b^k\n"
    "• T(n) = O(n^k log n) if a = b^k\n"
    "• T(n) = O(n^k) if a < b^k\n"
)

doc.add_paragraph(
    "Solve the following recurrence equation to determine the Big-O running time complexity:\n"
    "T(1) = 1\n"
    "T(n) = 8T(n/2) + 1\n"
)

doc.add_heading("3. Solve the Recurrence Using Iteration", level=2)
doc.add_paragraph(
    "Consider the following recurrence equation:\n"
    "T(n) = 2T(n-1) + 1\n\n"
    "With initial values:\n"
    "T(1) = 1, T(2) = 3, T(3) = 7, T(4) = 15, T(5) = 31, T(6) = 63\n\n"
    "Solve the equation using the iteration method to determine the Big-O running time complexity.\n"
)

doc.add_heading("4. Solve the Recurrence by Iteration", level=2)
doc.add_paragraph(
    "Consider the following recurrence equation:\n"
    "T(n) = 2T(n / 2) + n\n\n"
    "With initial values:\n"
    "T(1) = 1, T(2) = ?, T(4) = ?, T(8) = ?, T(16) = ?\n\n"
    "What is T(16)? (Your answer must be an integer.)\n"
)

doc.add_heading("5. Recurrence Equation for the Following Recursive Function", level=2)
doc.add_paragraph(
    "def f(a, n):  # First call: f(a, len(a))\n"
    "    if n > 0:\n"
    "        for i in range(7):\n"
    "            f(a, n // 4)\n"
    "            f(a, n // 4)\n"
    "            f(a, n // 4)\n"
    "        for i in range(n * n):\n"
    "            print(a[0])\n"
)

doc.add_heading("6. Write the Recurrence Equation for the Following Recursive Function", level=2)
doc.add_paragraph(
    "def f(t):\n"
    "    if t <= 5:\n"
    "        return t\n"
    "    return t * t * f(t / 10)\n"
)

doc.add_heading("Tracing Questions", level=2)
doc.add_paragraph(
    "Trace the execution of the following code cell using a recursion tree. Assign an ID to each node, starting from 0.\n\n"
    "def p1(n):\n"
    "    if n > 0:\n"
    "        p2(n // 4)\n"
    "        print(\"p1, n =\", n)\n\n"
    "def p2(n):\n"
    "    if n > 0:\n"
    "        p2(n - 1)\n"
    "        p1(n - 2)\n"
    "        print(\"p2, n =\", n)\n\n"
    "p1(5)\n\n"
    "1. How many nodes did you create? (The initial call to p1(n=5) counts as the zero-th node.)\n"
    "2. What is the value of n in node #3?\n"
    "3. What is the first line printed on the console?\n"
)

doc.add_heading("Time Complexity Analysis", level=2)

# Adding the remaining time complexity questions
time_complexity_questions = [
    ("10. Time Complexity of the Following Algorithm", "def f(nums):\n    for k in range(len(nums), 0, -100):\n"
     "        j = len(nums) + 1000\n        while j > 0:\n            print('hey')\n            j -= 10\n"),
    ("11. Time Complexity of the Following Algorithm", "def f(nums):\n    for i in range(len(nums) // 2):\n"
     "        for j in range(0, len(nums), 2):\n            print(\"Go Miners!\")\n"),
    ("12. Time Complexity of the Following Algorithm", "def f(nums_lst):\n    for i in range(len(nums_lst)):\n"
     "        if i < 10:\n            for k in range(len(nums_lst)):\n                print(nums_lst[0])\n"
     "        else:\n            j = 1\n            while j < len(nums_lst):\n                print(nums_lst[0])\n"
     "                j *= 2\n"),
    ("13. Time Complexity of the Following Algorithm", "def f(nums_lst):\n    for i in range(len(nums)):\n"
     "        if i >= 10:\n            for k in range(len(nums)):\n                print(nums[0])\n        else:\n"
     "            j = 1\n            while j < len(nums):\n                print(nums[0])\n                j *= 2\n"
     "    for i in range(len(nums)):\n        for k in range(len(nums) * len(nums)):\n            print(nums[0])\n"),
    ("14. Time Complexity of the Following Algorithm", "def f(nums_lst):\n    for i in range(len(nums_list)):\n"
     "        if i % 2 == 0:\n            print(\"hi\")\n        else:\n            for j in range(i - 1, -1, -1):\n"
     "                print(nums_list[0])\n"),
    ("15. Time Complexity of the Following Algorithm", "def f(nums_lst):\n    for i in range(len(nums_list)):\n"
     "        if i < len(nums_list) // 4:\n            print(\"hi\")\n        else:\n            for j in range(len(nums_list)):\n"
     "                print(nums_list[0])\n"),
    ("16. Time Complexity of the Following Algorithm", "def f(nums_lst):\n    n = len(nums_list)\n    for i in range(n * n):\n"
     "        if i >= 10:\n            print(\"hi\")\n        else:\n            j = len(nums_list)\n            while j > 0:\n"
     "                print(nums_list[j - 1])\n                j //= 2\n")
]

for title, code_block in time_complexity_questions:
    doc.add_heading(title, level=3)
    doc.add_paragraph(code_block)

# Save the document
doc_path = "/mnt/data/Practice_Problems_for_Exam.docx"
doc.save(doc_path)

doc_path
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-107e3a150a59> in <cell line: 1>()
# ----> 1 from docx import Document
#       2
#       3 # Create a new Document
#       4 doc = Document()
#       5
#
# ModuleNotFoundError: No module named 'docx'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
