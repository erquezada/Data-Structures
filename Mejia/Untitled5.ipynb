# %%
def test():
    for j in range(n):
        k = 1
        while k < n:
            print('*')
            k = k * 2

n = 2
print(n)
test()  # Just call the function without passing n
print(test())
# Out:
# 2
# *
# *
# *
# *
# None
