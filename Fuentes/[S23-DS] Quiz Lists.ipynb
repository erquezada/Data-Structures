# %% [markdown]
# # **CS 2302 Data Structures - Quiz - Lists**

# %% [markdown]
# What is the output of the following cell?

# %%
L = [50, 35, 20, 48, 36]
print(L[2])
# Out:
# 20

# %% [markdown]
# What is the output of the following cell?

# %%
L = [50, 35, 20, 48, 36]
print(len(L))
# Out:
# 5

# %% [markdown]
# What is the output of the following cell?

# %%
L = [50, 35, 20, 48, 36]
print(L[-2])
# Out:
# 48

# %% [markdown]
# What is the output of the following cell?

# %%
L = [50, 35, 20, 48, 36]
print(L[:2])
# Out:
# [50, 35]

# %% [markdown]
# What is the output of the following cell?

# %%
L = [50, 35, 20, 48, 36]
print(L[:20])
# Out:
# [50, 35, 20, 48, 36]

# %% [markdown]
# What is the output of the following cell?

# %%
L = [50, 35, 20, 48, 36]
print(L[2:])
# Out:
# [20, 48, 36]

# %% [markdown]
# What is the output of the following cell?

# %%
L = [50, 35, 20, 48, 36]
print(L[::2])
# Out:
# [50, 20, 36]

# %% [markdown]
# What is the output of the following cell?

# %%
L = [50, 35, 20, 48, 36, 66, 88]
print(L[1:5:2])
# Out:
# [35, 48]

# %% [markdown]
# What is the output of the following cell?

# %%
L = [3,6,9,12]
print(L+L)
# Out:
# [3, 6, 9, 12, 3, 6, 9, 12]

# %% [markdown]
# What is the output of the following cell?

# %%
L = [50, 35, 20, 48, 36]
for i in range(len(L)):
   print(i,end=' ')
# Out:
# 0 1 2 3 4

# %% [markdown]
# What is the output of the following cell?

# %%
L = [50, 35, 20, 48, 36]
for i in range(len(L)):
   print(L[i],end=' ')
# Out:
# 50 35 20 48 36

# %% [markdown]
# What is the output of the following cell?

# %%
L = [50, 35, 20, 48, 36]
for i in range(L):
   print(i,end=' ')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/ericquezada/Data-Structures/Fuentes/[S23-DS] Quiz Lists.ipynb Cell 25 line 2
#       <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/Fuentes/%5BS23-DS%5D%20Quiz%20Lists.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> L = [50, 35, 20, 48, 36]
# ----> <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/Fuentes/%5BS23-DS%5D%20Quiz%20Lists.ipynb#X33sZmlsZQ%3D%3D?line=1'>2</a> for i in range(L):
#       <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/Fuentes/%5BS23-DS%5D%20Quiz%20Lists.ipynb#X33sZmlsZQ%3D%3D?line=2'>3</a>    print(i,end=' ')
#
# TypeError: 'list' object cannot be interpreted as an integer

# %% [markdown]
# What is the output of the following cell?

# %%
L = [50, 35, 20, 48, 36]
for i in L:
   print(i,end=' ')
# Out:
# 50 35 20 48 36

# %% [markdown]
# What is the output of the following cell?

# %%
L = [50, 35, 20, 48, 36]
for i in L:
   print(L[i],end=' ')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/ericquezada/Data-Structures/Fuentes/[S23-DS] Quiz Lists.ipynb Cell 29 line 3
#       <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/Fuentes/%5BS23-DS%5D%20Quiz%20Lists.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> L = [50, 35, 20, 48, 36]
#       <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/Fuentes/%5BS23-DS%5D%20Quiz%20Lists.ipynb#X40sZmlsZQ%3D%3D?line=1'>2</a> for i in L:
# ----> <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/Fuentes/%5BS23-DS%5D%20Quiz%20Lists.ipynb#X40sZmlsZQ%3D%3D?line=2'>3</a>    print(L[i],end=' ')
#
# IndexError: list index out of range

# %% [markdown]
# What is the output of the following cell?

# %%
L = [50, 35, 20, 48, 36]
for a,b in enumerate(L):
    print(a,end=' ')
# Out:
# 0 1 2 3 4

# %% [markdown]
# What is the output of the following cell?

# %%
L = [50, 35, 20, 48, 36]
for a,b in enumerate(L):
    print(a, b)
# Out:
# 0 50
# 1 35
# 2 20
# 3 48
# 4 36

# %% [markdown]
# What is the output of the following cell?

# %%
L = [50, 35, 20, 48, 36]
M = [i//10 for i in L]
print(M)
# Out:
# [5, 3, 2, 4, 3]

# %% [markdown]
# What is the output of the following cell?

# %%
L =  [i for i in range(10) if i%2==0]
print(L)
# Out:
# [0, 2, 4, 6, 8]

# %% [markdown]
# What is the output of the following cell?

# %%
L = [1,3,6,7,3,2,1,8]
L1 =  [i if i%2==0 else -1 for i in L]
print(L1)
# Out:
# [-1, -1, 6, -1, -1, 2, -1, 8]
