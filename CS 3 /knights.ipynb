# %%
# Knight Tour
# Created by Leobardo Valera

import numpy as np

n = 8

board = [[0  for  j in range(n)] for i in range(n)]

#steps = [[2, 1], [1, 2],[-1, 2], [-2, 1], [-2, -1], [-1, -2], [1, -2],[2, -1]]
steps = [[-1, -2], [1, -2],[-2, -1], [2, -1], [2, 1], [1, 2], [-1, 2],[-2, 1]]

##############################################################

def safe_to_jump(x,y):
    global board
    if (x<0) or (x>n-1) or (y<0) or (y>n-1) or (board[x][y]!=0):
        return False
    return True

#############################################################

def knight(board,x,y,p):
    global backtracking
    if p == 64:
        return True

    for i in range(8):
        next_x = x+steps[i][0]
        next_y = y+steps[i][1]

        if safe_to_jump(next_x,next_y):
            board[next_x][next_y] = p+1
            if knight(board,next_x,next_y,p+1):
                return True
            bactracking = backtracking + 1
            board[next_x][next_y] = 0

    return False

#########################################################
backtracking = 0
p=1
board[0][0] = 1
knight(board,0,0,p)


print(np.matrix(board))
print(backtracking)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/ericquezada/Data-Structures/CS 3 /knights.ipynb Cell 1 line 4
#      <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=42'>43</a> p=1
#      <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=43'>44</a> board[0][0] = 1
# ---> <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=44'>45</a> knight(board,0,0,p)
#      <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=47'>48</a> print(np.matrix(board))
#      <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=48'>49</a> print(backtracking)
#
# /Users/ericquezada/Data-Structures/CS 3 /knights.ipynb Cell 1 line 3
#      <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=31'>32</a> if safe_to_jump(next_x,next_y):
#      <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=32'>33</a>     board[next_x][next_y] = p+1
# ---> <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=33'>34</a>     if knight(board,next_x,next_y,p+1):
#      <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=34'>35</a>         return True
#      <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=35'>36</a>     bactracking = backtracking + 1
#
# /Users/ericquezada/Data-Structures/CS 3 /knights.ipynb Cell 1 line 3
#      <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=31'>32</a> if safe_to_jump(next_x,next_y):
#      <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=32'>33</a>     board[next_x][next_y] = p+1
# ---> <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=33'>34</a>     if knight(board,next_x,next_y,p+1):
#      <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=34'>35</a>         return True
#      <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=35'>36</a>     bactracking = backtracking + 1
#
#     [... skipping similar frames: knight at line 34 (48 times)]
#
# /Users/ericquezada/Data-Structures/CS 3 /knights.ipynb Cell 1 line 3
#      <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=31'>32</a> if safe_to_jump(next_x,next_y):
#      <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=32'>33</a>     board[next_x][next_y] = p+1
# ---> <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=33'>34</a>     if knight(board,next_x,next_y,p+1):
#      <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=34'>35</a>         return True
#      <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=35'>36</a>     bactracking = backtracking + 1
#
# /Users/ericquezada/Data-Structures/CS 3 /knights.ipynb Cell 1 line 2
#      <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=25'>26</a>     return True
#      <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=27'>28</a> for i in range(8):
# ---> <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=28'>29</a>     next_x = x+steps[i][0]
#      <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=29'>30</a>     next_y = y+steps[i][1]
#      <a href='vscode-notebook-cell:/Users/ericquezada/Data-Structures/CS%203%20/knights.ipynb#W0sZmlsZQ%3D%3D?line=31'>32</a>     if safe_to_jump(next_x,next_y):
#
# KeyboardInterrupt:
